# %%
# ref: https://www.kaggle.com/code/shivamburnwal/speech-emotion-recognition/input
import sys
import os

import numpy as np
import pandas as pd
from glob import glob

import librosa
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from IPython.display import Audio

import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Precision, Recall

import warnings
if not sys.warnoptions:
    warnings.simplefilter('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %%
PATH_RAVDESS = "./raw_data/RAVDESS/"
PATH_CREMA = "./raw_data/CREMA-D/"
PATH_TESS = "./raw_data/TESS/"
PATH_SAVEE = "./raw_data/SAVEE/"

RANDOM_STATE = 11

# %% [markdown]
# ## Bug
# * [display waveshow error](https://github.com/matplotlib/matplotlib/issues/25506)

# %% [markdown]
# # Load Data

# %% [markdown]
# ### 1. RAVDESS
# Filename identifiers
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# * Vocal channel (01 = speech, 02 = song).
# * Emotion (01= neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disguest, 08 = surprised).
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# <p>Filename example: 03-01-06-01-02-01-12.wav</p>

# %%
ls_ravdess = glob(PATH_RAVDESS + 'Actor_0*/*')
ls_tmp = []
for fpath in ls_ravdess:
    fname = fpath.split('/')[-1].split('.')[0]
    modality, vocal_channel, emotion, emotional_intensity, statement, repetition, actor = [int(feat) for feat in fname.split('-')]
    ls_tmp.append([modality, vocal_channel, emotion, emotional_intensity, statement, repetition, actor, fpath])

df_ravdess = pd.DataFrame(ls_tmp, columns=['modality', 'vocal_channel', 'emotion', 'emotional_intensity', 'statetment', 'repetition', 'actor', 'fpath'])
dict_emotion_RAVDESS = {1: 'neutral', 2: 'calm', 3: 'happy', 4: 'sad', 5: 'angry', 6: 'fearful', 7: 'disguest', 8: 'surprised'}
df_ravdess['emotion'] = df_ravdess['emotion'].replace(dict_emotion_RAVDESS)
print('RAVDESS shape: ', df_ravdess.shape)
df_ravdess.head(3)
# Out:
# RAVDESS shape:  (540, 8)
#    modality  vocal_channel  emotion  emotional_intensity  statetment  \
# 0         3              1  neutral                    1           2
# 1         3              1    happy                    1           1
# 2         3              1    angry                    1           1
#
#    repetition  actor                                              fpath
# 0           2      3  ./raw_data/RAVDESS/Actor_03/03-01-01-01-02-02-...
# 1           1      3  ./raw_data/RAVDESS/Actor_03/03-01-03-01-01-01-...
# 2           1      3  ./raw_data/RAVDESS/Actor_03/03-01-05-01-01-01-...

# %% [markdown]
# ## Explore Data Analysis

# %%
def create_waveplot(data, sample_rate, emotino):
    fig, ax = plt.subplots(figsize=(8, 3))
    ax.set_title(f"Waveplot for audio with {emotion}.")
    librosa.display.waveshow(data, sr=sample_rate, ax=ax)

def create_spectrogram(data, sample_rate, emotion):
    fig, ax = plt.subplots(figsize=(6, 4))
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    ax.set_title(f'Spectrogram for audio with {emotion}')
    librosa.display.specshow(Xdb, sr=sample_rate, ax=ax, x_axis='time', y_axis='hz')

# %%
emotion = 'sad'
fpath = df_ravdess.loc[df_ravdess['emotion']==emotion, 'fpath'].iloc[0,]
data, sample_rate = librosa.load(fpath)
create_waveplot(data, sample_rate, emotion)
create_spectrogram(data, sample_rate, emotion)
Audio(fpath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Data Augmentation

# %%
def noise(data):
    noise_amp = 0.035 * np.random.uniform() * np.max(data)
    data = data + noise_amp * np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high=5) * 1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, n_steps=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=n_steps)

# %%
data_noise = noise(data)
data_stretch = stretch(data)
data_shift = shift(data)
data_pitch = pitch(data, sample_rate)

fig, axes = plt.subplots(3, 2, figsize=(14, 8))
axes[0][0].set_title('Original')
librosa.display.waveshow(y=data, sr=sample_rate, ax=axes[0][0])

axes[0][1].set_title('Noise')
librosa.display.waveshow(y=data_noise, sr=sample_rate, ax=axes[0][1])

axes[1][0].set_title('Stretch')
librosa.display.waveshow(y=data_stretch, sr=sample_rate, ax=axes[1][0])

axes[1][1].set_title('Shift')
librosa.display.waveshow(y=data_shift, sr=sample_rate, ax=axes[1][1])

axes[2][0].set_title('Pitch')
librosa.display.waveshow(y=data_pitch, sr=sample_rate, ax=axes[2][0])


plt.tight_layout()

# %% [markdown]
# ## Feature Extraction

# %%
def extract_features(data):
    # ZCR
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    
    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stf = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)

    result = np.hstack((zcr, chroma_stf, mfcc, rms, mel))
    return result

def get_features(path):
    result = np.array([])

    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    data_noise = noise(data)
    data_stretch = stretch(data)
    data_stretch_pitch = pitch(data_stretch, sample_rate)

    result = np.vstack((
        extract_features(data),
        extract_features(data_noise),
        extract_features(data_stretch_pitch)
    ))
    return result

# %%
ls_features = []
for i, row in df_ravdess.iterrows():
    features = get_features(row['fpath'])
    for feat in features:
        ls_features.append(list(feat) + [row['emotion']])

df_ravdess_feat = pd.DataFrame(ls_features)
df_ravdess_feat = df_ravdess_feat.rename(columns={len(df_ravdess_feat.columns)-1: 'label'})
print(df_ravdess_feat.shape)
df_ravdess_feat.to_csv('./features/ravdess_deat.csv', index=False)
df_ravdess_feat.head(3)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Data Preprocessing

# %%
X = df_ravdess_feat.iloc[:, :-1].values
y = df_ravdess_feat['label'].values

# %%
oh_encoder = OneHotEncoder()
y = oh_encoder.fit_transform(y.reshape(-1, 1)).toarray()

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, train_size=0.7, random_state=RANDOM_STATE)
print(f"{'Train X Shape':<15}: {train_X.shape}")
print(f"{'Train y Shape':<15}: {train_y.shape}")

print(f"{'Test X Shape':<15}: {test_X.shape}")
print(f"{'Test y Shape':<15}: {test_y.shape}")
# Out:
# Train X Shape  : (1134, 162)
# Train y Shape  : (1134, 8)
# Test X Shape   : (486, 162)
# Test y Shape   : (486, 8)

# %%
scaler = StandardScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

train_X = np.expand_dims(train_X, axis=2)
test_X = np.expand_dims(test_X, axis=2)

# %% [markdown]
# ## Model

# %%
BATCH_SIZE = 64
EPOCHS = 50
LR = 1e-4

# %%
def get_SER_model():
    model = Sequential()
    model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(train_X.shape[1], 1)))
    model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))

    model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))

    model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
    model.add(Dropout(0.2))

    model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))

    model.add(Flatten())
    model.add(Dense(units=32, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(units=8, activation='softmax'))
    optimizer = tf.keras.optimizers.Adam(lr=LR)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy', Precision(), Recall()])

    print(model.summary())

    return model

model = get_SER_model()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 162, 256)          1536
#
#  max_pooling1d_8 (MaxPooling  (None, 81, 256)          0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 81, 256)           327936
#
#  max_pooling1d_9 (MaxPooling  (None, 41, 256)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 41, 128)           163968
#
#  max_pooling1d_10 (MaxPoolin  (None, 21, 128)          0
#  g1D)
#
#  dropout_4 (Dropout)         (None, 21, 128)           0
#
#  conv1d_11 (Conv1D)          (None, 21, 64)            41024
#
#  max_pooling1d_11 (MaxPoolin  (None, 11, 64)           0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 704)               0
#
#  dense_4 (Dense)             (None, 32)                22560
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 557,288
# Trainable params: 557,288
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=1e-7)
history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(test_X, test_y), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 18/18 [==============================] - 3s 31ms/step - loss: 2.0261 - accuracy: 0.1667 - precision_2: 0.6667 - recall_2: 0.0247 - val_loss: 1.9577 - val_accuracy: 0.1893 - val_precision_2: 0.7222 - val_recall_2: 0.0267 - lr: 0.0010
# Epoch 2/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.9887 - accuracy: 0.1781 - precision_2: 0.6538 - recall_2: 0.0300 - val_loss: 1.9287 - val_accuracy: 0.2140 - val_precision_2: 0.8261 - val_recall_2: 0.0391 - lr: 0.0010
# Epoch 3/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.9544 - accuracy: 0.2196 - precision_2: 0.6984 - recall_2: 0.0388 - val_loss: 1.9010 - val_accuracy: 0.2572 - val_precision_2: 0.7600 - val_recall_2: 0.0391 - lr: 0.0010
# Epoch 4/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.9350 - accuracy: 0.2390 - precision_2: 0.6833 - recall_2: 0.0362 - val_loss: 1.8767 - val_accuracy: 0.2490 - val_precision_2: 0.7917 - val_recall_2: 0.0391 - lr: 0.0010
# Epoch 5/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.9019 - accuracy: 0.2778 - precision_2: 0.6462 - recall_2: 0.0370 - val_loss: 1.8312 - val_accuracy: 0.2840 - val_precision_2: 0.6136 - val_recall_2: 0.0556 - lr: 0.0010
# Epoch 6/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.8386 - accuracy: 0.2795 - precision_2: 0.6667 - recall_2: 0.0564 - val_loss: 1.8145 - val_accuracy: 0.3086 - val_precision_2: 0.7241 - val_recall_2: 0.0432 - lr: 0.0010
# Epoch 7/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.8421 - accuracy: 0.2945 - precision_2: 0.7848 - recall_2: 0.0547 - val_loss: 1.8392 - val_accuracy: 0.2860 - val_precision_2: 0.6078 - val_recall_2: 0.0638 - lr: 0.0010
# Epoch 8/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.7954 - accuracy: 0.3228 - precision_2: 0.7100 - recall_2: 0.0626 - val_loss: 1.7557 - val_accuracy: 0.3169 - val_precision_2: 0.5735 - val_recall_2: 0.0802 - lr: 0.0010
# Epoch 9/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.7432 - accuracy: 0.3201 - precision_2: 0.6806 - recall_2: 0.0864 - val_loss: 1.7283 - val_accuracy: 0.3724 - val_precision_2: 0.6000 - val_recall_2: 0.0617 - lr: 0.0010
# Epoch 10/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.6623 - accuracy: 0.3633 - precision_2: 0.7105 - recall_2: 0.1190 - val_loss: 1.7186 - val_accuracy: 0.3457 - val_precision_2: 0.5625 - val_recall_2: 0.0741 - lr: 0.0010
# Epoch 11/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.6652 - accuracy: 0.3527 - precision_2: 0.7011 - recall_2: 0.1076 - val_loss: 1.6955 - val_accuracy: 0.3868 - val_precision_2: 0.5914 - val_recall_2: 0.1132 - lr: 0.0010
# Epoch 12/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.6419 - accuracy: 0.3810 - precision_2: 0.6364 - recall_2: 0.1296 - val_loss: 1.6339 - val_accuracy: 0.4033 - val_precision_2: 0.6870 - val_recall_2: 0.1626 - lr: 0.0010
# Epoch 13/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.6103 - accuracy: 0.3907 - precision_2: 0.6867 - recall_2: 0.1411 - val_loss: 1.6416 - val_accuracy: 0.3498 - val_precision_2: 0.6364 - val_recall_2: 0.1152 - lr: 0.0010
# Epoch 14/50
# 18/18 [==============================] - 0s 14ms/step - loss: 1.5755 - accuracy: 0.4171 - precision_2: 0.6525 - recall_2: 0.1623 - val_loss: 1.6130 - val_accuracy: 0.4259 - val_precision_2: 0.7471 - val_recall_2: 0.1337 - lr: 0.0010
# Epoch 15/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.5132 - accuracy: 0.4268 - precision_2: 0.7407 - recall_2: 0.1764 - val_loss: 1.5667 - val_accuracy: 0.4321 - val_precision_2: 0.7266 - val_recall_2: 0.1914 - lr: 0.0010
# Epoch 16/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.4983 - accuracy: 0.4321 - precision_2: 0.7259 - recall_2: 0.2196 - val_loss: 1.5246 - val_accuracy: 0.4630 - val_precision_2: 0.7429 - val_recall_2: 0.1605 - lr: 0.0010
# Epoch 17/50
# 18/18 [==============================] - 0s 14ms/step - loss: 1.4547 - accuracy: 0.4647 - precision_2: 0.7385 - recall_2: 0.2116 - val_loss: 1.4874 - val_accuracy: 0.4527 - val_precision_2: 0.6894 - val_recall_2: 0.2284 - lr: 0.0010
# Epoch 18/50
# 18/18 [==============================] - 0s 14ms/step - loss: 1.4287 - accuracy: 0.4709 - precision_2: 0.7047 - recall_2: 0.2399 - val_loss: 1.5162 - val_accuracy: 0.4506 - val_precision_2: 0.6978 - val_recall_2: 0.1996 - lr: 0.0010
# Epoch 19/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.4735 - accuracy: 0.4480 - precision_2: 0.6971 - recall_2: 0.2152 - val_loss: 1.5074 - val_accuracy: 0.4321 - val_precision_2: 0.6818 - val_recall_2: 0.1852 - lr: 0.0010
# Epoch 20/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.3974 - accuracy: 0.4806 - precision_2: 0.7493 - recall_2: 0.2478 - val_loss: 1.4442 - val_accuracy: 0.4815 - val_precision_2: 0.7368 - val_recall_2: 0.2305 - lr: 0.0010
# Epoch 21/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.3214 - accuracy: 0.5106 - precision_2: 0.7675 - recall_2: 0.2998 - val_loss: 1.4378 - val_accuracy: 0.5062 - val_precision_2: 0.7231 - val_recall_2: 0.2901 - lr: 0.0010
# Epoch 22/50
# 18/18 [==============================] - 0s 16ms/step - loss: 1.3536 - accuracy: 0.4965 - precision_2: 0.7313 - recall_2: 0.2760 - val_loss: 1.3925 - val_accuracy: 0.4774 - val_precision_2: 0.7308 - val_recall_2: 0.2737 - lr: 0.0010
# Epoch 23/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.2454 - accuracy: 0.5282 - precision_2: 0.7645 - recall_2: 0.3263 - val_loss: 1.4597 - val_accuracy: 0.4794 - val_precision_2: 0.6826 - val_recall_2: 0.3230 - lr: 0.0010
# Epoch 24/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.1902 - accuracy: 0.5511 - precision_2: 0.7518 - recall_2: 0.3686 - val_loss: 1.3833 - val_accuracy: 0.5123 - val_precision_2: 0.6777 - val_recall_2: 0.2942 - lr: 0.0010
# Epoch 25/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.1655 - accuracy: 0.5564 - precision_2: 0.7491 - recall_2: 0.3739 - val_loss: 1.3723 - val_accuracy: 0.5206 - val_precision_2: 0.7076 - val_recall_2: 0.3436 - lr: 0.0010
# Epoch 26/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.1664 - accuracy: 0.5564 - precision_2: 0.7750 - recall_2: 0.3827 - val_loss: 1.3349 - val_accuracy: 0.5000 - val_precision_2: 0.6886 - val_recall_2: 0.3230 - lr: 0.0010
# Epoch 27/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.1838 - accuracy: 0.5573 - precision_2: 0.7653 - recall_2: 0.3739 - val_loss: 1.2901 - val_accuracy: 0.5412 - val_precision_2: 0.7309 - val_recall_2: 0.3354 - lr: 0.0010
# Epoch 28/50
# 18/18 [==============================] - 0s 15ms/step - loss: 1.0450 - accuracy: 0.6155 - precision_2: 0.8138 - recall_2: 0.4162 - val_loss: 1.2680 - val_accuracy: 0.5453 - val_precision_2: 0.7090 - val_recall_2: 0.3909 - lr: 4.0000e-04
# Epoch 29/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.9868 - accuracy: 0.6384 - precision_2: 0.8057 - recall_2: 0.4753 - val_loss: 1.2553 - val_accuracy: 0.5576 - val_precision_2: 0.7011 - val_recall_2: 0.3909 - lr: 4.0000e-04
# Epoch 30/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.9929 - accuracy: 0.6279 - precision_2: 0.8071 - recall_2: 0.4797 - val_loss: 1.2431 - val_accuracy: 0.5350 - val_precision_2: 0.7245 - val_recall_2: 0.3951 - lr: 4.0000e-04
# Epoch 31/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.9682 - accuracy: 0.6481 - precision_2: 0.8252 - recall_2: 0.4788 - val_loss: 1.2337 - val_accuracy: 0.5267 - val_precision_2: 0.7306 - val_recall_2: 0.4074 - lr: 4.0000e-04
# Epoch 32/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.9610 - accuracy: 0.6517 - precision_2: 0.8077 - recall_2: 0.4780 - val_loss: 1.1896 - val_accuracy: 0.5658 - val_precision_2: 0.7500 - val_recall_2: 0.4259 - lr: 4.0000e-04
# Epoch 33/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.8723 - accuracy: 0.6720 - precision_2: 0.8422 - recall_2: 0.5176 - val_loss: 1.1940 - val_accuracy: 0.5802 - val_precision_2: 0.7426 - val_recall_2: 0.4630 - lr: 4.0000e-04
# Epoch 34/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.8695 - accuracy: 0.6834 - precision_2: 0.8288 - recall_2: 0.5379 - val_loss: 1.2049 - val_accuracy: 0.5761 - val_precision_2: 0.7233 - val_recall_2: 0.4465 - lr: 4.0000e-04
# Epoch 35/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.8522 - accuracy: 0.6896 - precision_2: 0.8556 - recall_2: 0.5432 - val_loss: 1.1948 - val_accuracy: 0.5782 - val_precision_2: 0.7240 - val_recall_2: 0.4588 - lr: 4.0000e-04
# Epoch 36/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.8384 - accuracy: 0.6808 - precision_2: 0.8420 - recall_2: 0.5450 - val_loss: 1.2195 - val_accuracy: 0.5844 - val_precision_2: 0.7086 - val_recall_2: 0.4753 - lr: 4.0000e-04
# Epoch 37/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.8302 - accuracy: 0.6869 - precision_2: 0.8294 - recall_2: 0.5573 - val_loss: 1.2135 - val_accuracy: 0.5658 - val_precision_2: 0.6918 - val_recall_2: 0.4527 - lr: 4.0000e-04
# Epoch 38/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.8230 - accuracy: 0.6922 - precision_2: 0.8286 - recall_2: 0.5714 - val_loss: 1.1614 - val_accuracy: 0.5823 - val_precision_2: 0.7407 - val_recall_2: 0.4527 - lr: 4.0000e-04
# Epoch 39/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.7377 - accuracy: 0.7416 - precision_2: 0.8646 - recall_2: 0.6023 - val_loss: 1.1903 - val_accuracy: 0.5782 - val_precision_2: 0.6963 - val_recall_2: 0.4671 - lr: 4.0000e-04
# Epoch 40/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.7718 - accuracy: 0.7169 - precision_2: 0.8445 - recall_2: 0.5891 - val_loss: 1.1977 - val_accuracy: 0.5967 - val_precision_2: 0.7139 - val_recall_2: 0.4877 - lr: 4.0000e-04
# Epoch 41/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.7633 - accuracy: 0.7187 - precision_2: 0.8617 - recall_2: 0.5935 - val_loss: 1.2064 - val_accuracy: 0.5741 - val_precision_2: 0.6933 - val_recall_2: 0.4650 - lr: 4.0000e-04
# Epoch 42/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.7206 - accuracy: 0.7451 - precision_2: 0.8577 - recall_2: 0.6111 - val_loss: 1.1418 - val_accuracy: 0.5947 - val_precision_2: 0.7406 - val_recall_2: 0.4877 - lr: 1.6000e-04
# Epoch 43/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6867 - accuracy: 0.7496 - precision_2: 0.8694 - recall_2: 0.6279 - val_loss: 1.1463 - val_accuracy: 0.5823 - val_precision_2: 0.7012 - val_recall_2: 0.4877 - lr: 1.6000e-04
# Epoch 44/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6663 - accuracy: 0.7610 - precision_2: 0.8841 - recall_2: 0.6393 - val_loss: 1.1555 - val_accuracy: 0.5782 - val_precision_2: 0.6901 - val_recall_2: 0.5041 - lr: 1.6000e-04
# Epoch 45/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.6628 - accuracy: 0.7531 - precision_2: 0.8754 - recall_2: 0.6570 - val_loss: 1.1404 - val_accuracy: 0.5844 - val_precision_2: 0.6895 - val_recall_2: 0.4979 - lr: 1.6000e-04
# Epoch 46/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.6397 - accuracy: 0.7725 - precision_2: 0.8716 - recall_2: 0.6526 - val_loss: 1.1578 - val_accuracy: 0.5720 - val_precision_2: 0.6901 - val_recall_2: 0.5041 - lr: 1.6000e-04
# Epoch 47/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.6411 - accuracy: 0.7743 - precision_2: 0.8756 - recall_2: 0.6455 - val_loss: 1.1577 - val_accuracy: 0.5823 - val_precision_2: 0.7131 - val_recall_2: 0.5165 - lr: 1.6000e-04
# Epoch 48/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6130 - accuracy: 0.7875 - precision_2: 0.8878 - recall_2: 0.6905 - val_loss: 1.1569 - val_accuracy: 0.5844 - val_precision_2: 0.6975 - val_recall_2: 0.5123 - lr: 1.6000e-04
# Epoch 49/50
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6208 - accuracy: 0.7892 - precision_2: 0.8931 - recall_2: 0.6781 - val_loss: 1.1540 - val_accuracy: 0.5864 - val_precision_2: 0.7003 - val_recall_2: 0.5144 - lr: 1.6000e-04
# Epoch 50/50
# 18/18 [==============================] - 0s 16ms/step - loss: 0.6123 - accuracy: 0.7901 - precision_2: 0.9005 - recall_2: 0.6861 - val_loss: 1.1403 - val_accuracy: 0.6029 - val_precision_2: 0.7107 - val_recall_2: 0.5309 - lr: 1.6000e-04

# %%
history.history.keys()
def plot_loss(history):
    history = history.history
    train_loss, train_acc = history['loss'], history['accuracy']
    test_loss, test_acc = history['val_loss'], history['val_accuracy']
    epoch = list(range(1, EPOCHS+1))

    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    plt.suptitle('Training History')
    axes[0].plot(epoch, train_loss, label='train_loss')
    axes[0].plot(epoch, test_loss, label='test_loss')
    axes[0].set_xlabel('Epochs'), axes[0].set_ylabel('Loss'), axes[0].legend()

    axes[1].plot(epoch, train_acc, label='train_acc')
    axes[1].plot(epoch, test_acc, label='test_acc')
    axes[1].set_xlabel('Epochs'), axes[1].set_ylabel('Accuracy'), axes[1].legend()

plot_loss(history)

# %%
pred_y = model.predict(test_X)
pred_y_in = oh_encoder.inverse_transform(pred_y)
test_y_in = oh_encoder.inverse_transform(test_y)
print(classification_report(test_y_in, pred_y_in))
# Out:
# 16/16 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#        angry       0.73      0.55      0.62        73
#         calm       0.70      0.77      0.73        74
#     disguest       0.47      0.59      0.52        63
#      fearful       0.64      0.54      0.59        68
#        happy       0.59      0.51      0.54        67
#      neutral       0.25      0.18      0.21        28
#          sad       0.53      0.67      0.59        55
#    surprised       0.71      0.79      0.75        58
#
#     accuracy                           0.60       486
#    macro avg       0.58      0.58      0.57       486
# weighted avg       0.61      0.60      0.60       486

# %%
cm = pd.DataFrame(confusion_matrix(test_y_in, pred_y), index=[i for i in oh_encoder.categories_], columns=[i for i in oh_encoder.categories_])

fig, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(cm, linecolor='white', cmap='Blues', annot=True, ax=ax)
ax.set_title('Confusion Matrix')
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('Actual Labels')
